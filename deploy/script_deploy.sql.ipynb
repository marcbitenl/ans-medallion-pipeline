# %% [markdown]
# ## Ordem de execução do deploy
#
# Este script define a ordem de execução dos componentes responsáveis pela criação da estrutura de dados do projeto.
#
# A execução contempla apenas a camada de infraestrutura, incluindo catálogo, schemas, volumes e tabelas.
#
# ### Etapas
#
# 1. Criação de catálogo e schemas
# 2. Criação dos volumes (landing zone)
# 3. Criação das tabelas (Bronze, Silver e Gold)
#
#
# **Data Engineer Responsável:** Marcos Bitencourt Leal

# %%
dbutils.notebook.run("/Users/logmarcbitenl@outlook.com/ans-medallion-pipeline/deploy/01_catalog.sql",100)
dbutils.notebook.run("/Users/logmarcbitenl@outlook.com/ans-medallion-pipeline/deploy/02_schemas.sql", 100)
dbutils.notebook.run("/Users/logmarcbitenl@outlook.com/ans-medallion-pipeline/deploy/03_volumes.sql", 100)
dbutils.notebook.run("/Users/logmarcbitenl@outlook.com/ans-medallion-pipeline/deploy/04_create_table.sql", 100)
