# %% [markdown]
# ## Criação dos schemas
#
# Criação dos schemas seguindo a arquitetura Medallion:
# - `brz`: camada bruta (raw)
# - `slv`: camada tratada (refined)
# - `gld`: camada analítica (curated)

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS brz;
CREATE SCHEMA IF NOT EXISTS slv;
CREATE SCHEMA IF NOT EXISTS gld;
