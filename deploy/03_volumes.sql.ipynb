# %% [markdown]
# ## Criação dos volumes
#
# Criação das zonas de armazenamento para cada camada do pipeline:
# - `vl_landing`: dados brutos
# - `vl_refined`: dados tratados
# - `vl_curated`: dados prontos para análise

# %%
# %sql
USE CATALOG dev

# %%
# %sql
CREATE VOLUME IF NOT EXISTS brz.vl_landing;
CREATE VOLUME IF NOT EXISTS slv.vl_refined;
CREATE VOLUME IF NOT EXISTS gld.vl_curated;
