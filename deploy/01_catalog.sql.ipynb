# %% [markdown]
# ## Criação do catálogo
# Este passo cria o catálogo `dev`, responsável por centralizar os objetos do pipeline.
# Também define o contexto padrão para execução dos próximos comandos.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS dev;

# %%
# %sql
USE CATALOG dev;
